# %%
import shutil

# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/home/renton/Documents/code/fast-app'

# %%
import pathlib

# %%
title_info = pathlib.Path('./data/title.basics.tsv').resolve()
df = pd.read_csv(
        title_info,
        delimiter='\t',
        index_col=['tconst'],
        na_values=['\\N'],
        low_memory=False
    )

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
await df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 await df
#
# TypeError: object DataFrame can't be used in 'await' expression

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11456853 entries, tt0000001 to tt9916880
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   titleType       object
#  1   primaryTitle    object
#  2   originalTitle   object
#  3   isAdult         float64
#  4   startYear       float64
#  5   endYear         float64
#  6   runtimeMinutes  object
#  7   genres          object
# dtypes: float64(3), object(5)
# memory usage: 786.7+ MB

# %%
is_num = df['runtimeMinutes'].str.isnumeric()

# %%
is_num
# Out:
# tconst
# tt0000001    True
# tt0000002    True
# tt0000003    True
# tt0000004    True
# tt0000005    True
#              ...
# tt9916848     NaN
# tt9916850     NaN
# tt9916852     NaN
# tt9916856    True
# tt9916880    True
# Name: runtimeMinutes, Length: 11456853, dtype: object

# %%
is_num = is_num.astype('bool')

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
cf = df.copy()

# %%
cf
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
cf[:'runtimeMinutes'] = 0

# %%
cf
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
cf[:'runtimeMinutes'] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 cf[:'runtimeMinutes'] = 0
#
# TypeError: 'int' object does not support item assignment

# %%
cf
# Out:
# 0

# %%
cf = df.copy()

# %%
cf[:'runtimeMinutes'] = 0

# %%
cf
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
title_info = pathlib.Path('./data/title.basics.tsv').resolve()
df = pd.read_csv(
        title_info,
        delimiter='\t',
        index_col=['tconst'],
        na_values=['\\N'],
        low_memory=False
    )

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
is_numeric = df['runtimeMinutes'].str.isnumeric()

# %%
is_numeric
# Out:
# tconst
# tt0000001    True
# tt0000002    True
# tt0000003    True
# tt0000004    True
# tt0000005    True
#              ...
# tt9916848     NaN
# tt9916850     NaN
# tt9916852     NaN
# tt9916856    True
# tt9916880    True
# Name: runtimeMinutes, Length: 11456853, dtype: object

# %%
is_numeric = is_numeric.astype('bool')

# %%
is_numeric
# Out:
# tconst
# tt0000001    True
# tt0000002    True
# tt0000003    True
# tt0000004    True
# tt0000005    True
#              ...
# tt9916848    True
# tt9916850    True
# tt9916852    True
# tt9916856    True
# tt9916880    True
# Name: runtimeMinutes, Length: 11456853, dtype: bool

# %%
df[~is_numeric]
# Out:
#             titleType                                       primaryTitle  \
# tconst
# tt10233364  tvEpisode  Rolling in the Deep Dish\tRolling in the Deep ...
# tt10970874  tvEpisode  Die Bauhaus-Stadt Tel Aviv - Vorbild für die M...
# tt11670006  tvEpisode  ...ein angenehmer Unbequemer...\t...ein angene...
# tt11868642  tvEpisode  GGN Heavyweight Championship Lungs With Mike T...
# tt12149332  tvEpisode  Jeopardy! College Championship Semifinal Game ...
# ...               ...                                                ...
# tt35660466  tvEpisode       House of Frankenstein\tHouse of Frankenstein
# tt35718114  tvEpisode                               Night Key\tNight Key
# tt3984412   tvEpisode  I'm Not Going to Come Last, I'm Just Going to ...
# tt9822816   tvEpisode  Zwischen Vertuschung und Aufklärung - Missbrau...
# tt9909210   tvEpisode  Politik und/oder Moral - Wie weit geht das Ver...
#
#            originalTitle  isAdult  startYear  endYear          runtimeMinutes  \
# ...

# %%
df = df[is_numeric]

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
df.dtypes
# Out:
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
is_numeric_cleaned = df['runtimeMinutes'].str.isnumeric().astype('bool')
df[~is_numeric_cleaned]
# Out:
# Empty DataFrame
# Columns: [titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
df.loc[:, 'runtimeMinutes'] = pd.to_numeric(
    df.loc[:, 'runtimeMinutes'], errors='coerce'
)
df.dtypes
# Out:
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
df.dtypes
# Out:
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
df.dtypes
# Out:
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
is_numeric_cleaned = df['runtimeMinutes'].str.isnumeric().astype('bool')
df[~is_numeric_cleaned]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 is_numeric_cleaned = df['runtimeMinutes'].str.isnumeric().astype('bool')
#       2 df[~is_numeric_cleaned]
#
# File ~/Documents/code/fast-app/.virtualenv/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~/Documents/code/fast-app/.virtualenv/lib/python3.12/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df['runtimeMinutes'].notnull()
# Out:
# tconst
# tt0000001     True
# tt0000002     True
# tt0000003     True
# tt0000004     True
# tt0000005     True
#              ...
# tt9916848    False
# tt9916850    False
# tt9916852    False
# tt9916856     True
# tt9916880     True
# Name: runtimeMinutes, Length: 11456030, dtype: bool

# %%
df.info
# Out:
# <bound method DataFrame.info of            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
# ...

# %%
df.dtypes
# Out:
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult           float64
# startYear         float64
# endYear           float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
nulls = df['runtimeMinutes'].notnull()

# %%
df[nulls]
# Out:
#            titleType                    primaryTitle  \
# tconst
# tt0000001      short                      Carmencita
# tt0000002      short          Le clown et ses chiens
# tt0000003      short                    Poor Pierrot
# tt0000004      short                     Un bon bock
# tt0000005      short                Blacksmith Scene
# ...              ...                             ...
# tt9916754      movie  Chico Albuquerque - Revelações
# tt9916766  tvEpisode                  Episode #10.15
# tt9916840  tvEpisode      Horrid Henry's Comic Caper
# tt9916856      short                        The Wind
# tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                             originalTitle  isAdult  startYear  endYear  \
# tconst
# tt0000001                      Carmencita      0.0     1894.0      NaN
# tt0000002          Le clown et ses chiens      0.0     1892.0      NaN
# tt0000003                  Pauvre Pierrot      0.0     1892.0      NaN
# ...

# %%
nulls
# Out:
# tconst
# tt0000001     True
# tt0000002     True
# tt0000003     True
# tt0000004     True
# tt0000005     True
#              ...
# tt9916848    False
# tt9916850    False
# tt9916852    False
# tt9916856     True
# tt9916880     True
# Name: runtimeMinutes, Length: 11456030, dtype: bool

# %%
nulls.unique()
# Out:
# array([ True, False])

# %%
nulls.unique().count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 nulls.unique().count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
nulls.unique()
# Out:
# array([ True, False])

# %%
nulls
# Out:
# tconst
# tt0000001     True
# tt0000002     True
# tt0000003     True
# tt0000004     True
# tt0000005     True
#              ...
# tt9916848    False
# tt9916850    False
# tt9916852    False
# tt9916856     True
# tt9916880     True
# Name: runtimeMinutes, Length: 11456030, dtype: bool

# %%
df[nulls]
# Out:
#            titleType                    primaryTitle  \
# tconst
# tt0000001      short                      Carmencita
# tt0000002      short          Le clown et ses chiens
# tt0000003      short                    Poor Pierrot
# tt0000004      short                     Un bon bock
# tt0000005      short                Blacksmith Scene
# ...              ...                             ...
# tt9916754      movie  Chico Albuquerque - Revelações
# tt9916766  tvEpisode                  Episode #10.15
# tt9916840  tvEpisode      Horrid Henry's Comic Caper
# tt9916856      short                        The Wind
# tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                             originalTitle  isAdult  startYear  endYear  \
# tconst
# tt0000001                      Carmencita      0.0     1894.0      NaN
# tt0000002          Le clown et ses chiens      0.0     1892.0      NaN
# tt0000003                  Pauvre Pierrot      0.0     1892.0      NaN
# ...

# %%
df[~nulls]
# Out:
#            titleType                                   primaryTitle  \
# tconst
# tt0000019      short                               The Clown Barber
# tt0000025      short  The Oxford and Cambridge University Boat Race
# tt0000039      short                              Barnet Horse Fair
# tt0000040      short            Barque sortant du port de Trouville
# tt0000042      short                     Bateau-mouche sur la Seine
# ...              ...                                            ...
# tt9916844  tvEpisode                                  Episode #3.15
# tt9916846  tvEpisode                                  Episode #3.18
# tt9916848  tvEpisode                                  Episode #3.17
# tt9916850  tvEpisode                                  Episode #3.19
# tt9916852  tvEpisode                                  Episode #3.20
#
#                                            originalTitle  isAdult  startYear  \
# tconst
# ...

# %%
df[~nulls]['runtimeMinutes'] = 0
# Out:
# /tmp/ipykernel_88617/783235193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[~nulls]['runtimeMinutes'] = 0

# %%
df[~nulls][:'runtimeMinutes'] = 0
# Out:
# /tmp/ipykernel_88617/294594173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[~nulls][:'runtimeMinutes'] = 0

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear runtimeMinutes  \
# ...

# %%
df[~nulls]['runtimeMinutes']
# Out:
# tconst
# tt0000019    NaN
# tt0000025    NaN
# tt0000039    NaN
# tt0000040    NaN
# tt0000042    NaN
#             ...
# tt9916844    NaN
# tt9916846    NaN
# tt9916848    NaN
# tt9916850    NaN
# tt9916852    NaN
# Name: runtimeMinutes, Length: 7819473, dtype: object

# %%
df['runtimeMinutes'] = df['runtimeMinutes'].fillna(0)
# Out:
# /tmp/ipykernel_88617/1759827573.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['runtimeMinutes'] = df['runtimeMinutes'].fillna(0)
# /tmp/ipykernel_88617/1759827573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runtimeMinutes'] = df['runtimeMinutes'].fillna(0)

# %%
df
# Out:
#            titleType               primaryTitle              originalTitle  \
# tconst
# tt0000001      short                 Carmencita                 Carmencita
# tt0000002      short     Le clown et ses chiens     Le clown et ses chiens
# tt0000003      short               Poor Pierrot             Pauvre Pierrot
# tt0000004      short                Un bon bock                Un bon bock
# tt0000005      short           Blacksmith Scene           Blacksmith Scene
# ...              ...                        ...                        ...
# tt9916848  tvEpisode              Episode #3.17              Episode #3.17
# tt9916850  tvEpisode              Episode #3.19              Episode #3.19
# tt9916852  tvEpisode              Episode #3.20              Episode #3.20
# tt9916856      short                   The Wind                   The Wind
# tt9916880  tvEpisode  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#            isAdult  startYear  endYear  runtimeMinutes  \
# ...
