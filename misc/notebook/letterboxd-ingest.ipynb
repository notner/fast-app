# %%
import pandas as pd
import numpy as np
import pathlib

imdb_data_dir = pathlib.Path('../../code/letterbox-data').resolve()

# ratings
ratings = pd.read_csv(
        pathlib.Path(imdb_data_dir / 'ratings.csv'),
        delimiter=',',
        low_memory=False
)

# change name to lower, and remove spaces
ratings['Name'] = ratings['Name'].str.lower() 
ratings['Name'] = ratings['Name'].str.strip().replace(r'\s+', '', regex=True)
ratings['Name'] = ratings['Name'].astype('string')

# %%
### from other sheet #####
import pandas as pd
import numpy as np
import pathlib
titles = pd.read_csv(
        pathlib.Path('./data/title.basics.tsv').resolve(),
        delimiter='\t',
        index_col=['tconst'],
        na_values=['\\N'],
        low_memory=False
)
imdb_ratings = pd.read_csv(
        pathlib.Path('./data/title.ratings.tsv').resolve(),
        delimiter='\t',
        index_col=['tconst'],
        na_values=['\\N'],
        low_memory=False
)

# Combine data-sources on 'tconst' (works like left inner join)
df = pd.merge(titles, imdb_ratings, on="tconst")

# Clean up runtimeMinutes data
df['runtimeMinutes'] = df['runtimeMinutes'].fillna(0)
df = df[df['runtimeMinutes'].str.isnumeric().astype('bool')].copy()
df['runtimeMinutes'] = pd.to_numeric(df['runtimeMinutes'])
################################

# %%
df['Name'] = df['originalTitle'].str.lower() 
df['Name'] = df['Name'].str.strip().replace(r'\s+', '', regex=True)
df['Name'] = df['Name'].astype(str)
# Out:
# Date               object
# Name               object
# Year              float64
# Letterboxd URI     object
# Rating            float64
# dtype: object

# %%
#movies = df.iloc[np.where(df.titleType == 'movie')].copy()

# pd.merge(movies, ratings, left_on=['Name', 'startYear'], right_on=['Name', 'Year'], how='right')

movies
# Out:
#           titleType                   primaryTitle  \
# tconst
# tt0000009     movie                     Miss Jerry
# tt0000147     movie  The Corbett-Fitzsimmons Fight
# tt0000502     movie                       Bohemios
# tt0000574     movie    The Story of the Kelly Gang
# tt0000591     movie               The Prodigal Son
# ...             ...                            ...
# tt9916362     movie                          Coven
# tt9916428     movie            The Secret of China
# tt9916538     movie            Kuambil Lagi Hatiku
# tt9916706     movie                Dankyavar Danka
# tt9916730     movie                         6 Gunn
#
#                            originalTitle  isAdult  startYear  endYear  \
# tconst
# tt0000009                     Miss Jerry      0.0     1894.0      NaN
# tt0000147  The Corbett-Fitzsimmons Fight      0.0     1897.0      NaN
# tt0000502                       Bohemios      0.0     1905.0      NaN
# ...
